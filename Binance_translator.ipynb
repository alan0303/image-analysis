# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# %%
pip install azure-ai-formrecognizer==3.2.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install azure-ai-ml
# !pip install azure-identity

# %%
endpoint = "https://gaiadocint.cognitiveservices.azure.com/"
key = "70530d26a42145eab342bf6e76130321"

# %%
def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

# %%
formUrl = "https://public.bnbstatic.com/image/cms/blog/20230220/8e5dbeb4-f0b9-4397-a456-8702e7436fa6.jpg"

# %%
# formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"

document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

poller = document_analysis_client.begin_analyze_document_from_url(
        "prebuilt-read", formUrl)
result = poller.result()

print ("Document contains content: ", result.content)

for idx, style in enumerate(result.styles):
    print(
        "Document contains {} content".format(
            "handwritten" if style.is_handwritten else "no handwritten"
        )
    )

for page in result.pages:
    print("----Analyzing Read from page #{}----".format(page.page_number))
    print(
        "Page has width: {} and height: {}, measured with unit: {}".format(
            page.width, page.height, page.unit
        )
    )

    for line_idx, line in enumerate(page.lines):
        print(
            "...Line # {} has text content '{}' within bounding box '{}'".format(
                line_idx,
                line.content,
                format_bounding_box(line.polygon),
            )
        )

    for word in page.words:
        print(
            "...Word '{}' has a confidence of {}".format(
                word.content, word.confidence
            )
        )

print("----------------------------------------")
# Out:
# Document contains content:  BINANCE
# THE BINANCE CULTURE
# Vision
# Mission
# Our vision is to increase the freedom of money globally. We believe that by spreading this freedom, we can significantly improve lives around the world. People have the freedom to access, spend, own, store, and earn money.
# Our mission is to provide core infrastructure services for organizing the world's crypto.
# Core Values
# Everything we do is guided by these values
# User focused
# Users and the community is why we exist. Our job is to service and protect the users by putting them and their interests first.
# Behaviors
# As we grow and evolve, here's how we must act to bring our Core Values to life
# Freedom We execute responsibly and autonomously. We empower those around us. Our team is diverse and we challenge the status quo.
# Collaboration We communicate openly. We work as a team towards shared goals to build the ecosystem together.
# Communicate Effectively
# ...

# %%
print ("Document contains content: ", result.content)
# Out:
# Document contains content:  BINANCE
# THE BINANCE CULTURE
# Vision
# Mission
# Our vision is to increase the freedom of money globally. We believe that by spreading this freedom, we can significantly improve lives around the world. People have the freedom to access, spend, own, store, and earn money.
# Our mission is to provide core infrastructure services for organizing the world's crypto.
# Core Values
# Everything we do is guided by these values
# User focused
# Users and the community is why we exist. Our job is to service and protect the users by putting them and their interests first.
# Behaviors
# As we grow and evolve, here's how we must act to bring our Core Values to life
# Freedom We execute responsibly and autonomously. We empower those around us. Our team is diverse and we challenge the status quo.
# Collaboration We communicate openly. We work as a team towards shared goals to build the ecosystem together.
# Communicate Effectively
# ...

# %%
import requests, uuid, json

# Add your key and endpoint
key = "3058c4b0b7234da5b808683fbbca0c80"
endpoint = "https://api.cognitive.microsofttranslator.com"

# location, also known as region.
# required if you're using a multi-service or regional (not global) resource. It can be found in the Azure portal on the Keys and Endpoint page.
location = "eastus"

path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': ['ja', 'zh-Hant']
}

headers = {
    'Ocp-Apim-Subscription-Key': key,
    # location required if you're using a multi-service or regional (not global) resource.
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': result.content
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 33
#      28 # You can pass more than one object in body.
#      29 body = [{
#      30     'text': result
#      31 }]
# ---> 33 request = requests.post(constructed_url, params=params, headers=headers, json=body)
#      34 response = request.json()
#      36 print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
#
# File c:\Users\Alan\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# ...
